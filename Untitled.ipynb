# %%
import os
from pathlib import Path
import multiprocessing as mp

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from skimage.data import imread
from sklearn.ensemble import RandomForestClassifier

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "input"]).decode("utf8"))

# %%
input_path = Path('input')
train_path = '/home/mashrin/Downloads/camera/input/train'
#print (train_path)
test_path = '/home/mashrin/Downloads/camera/input/test1'
os.listdir(train_path)
# Out:
# ['LG-Nexus-5x',
#  'Motorola-X',
#  'iPhone-4s',
#  'Sony-NEX-7',
#  'Samsung-Galaxy-Note3',
#  'Motorola-Nexus-6',
#  'Samsung-Galaxy-S4',
#  'HTC-1-M7',
#  'Motorola-Droid-Maxx',
#  'iPhone-6']

# %%
cameras = os.listdir(train_path)

train_images = []
for camera in cameras:
    for fname in sorted(os.listdir('/home/mashrin/Downloads/camera/input/train')):
        train_images.append((camera, fname))

train = pd.DataFrame(train_images, columns=['camera', 'fname'])
print(train.shape)
train.sample(5)
# Out:
# (100, 2)
#                   camera                 fname
# 49  Samsung-Galaxy-Note3              iPhone-6
# 22             iPhone-4s   Motorola-Droid-Maxx
# 24             iPhone-4s            Motorola-X
# 50      Motorola-Nexus-6              HTC-1-M7
# 75              HTC-1-M7  Samsung-Galaxy-Note3

# %%
test_images = []
for fname in sorted(os.listdir(test_path)):
    test_images.append(fname)

test = pd.DataFrame(test_images, columns=['fname'])
print(test.shape)
test.head(5)
# Out:
# (70, 1)
#               fname
# 0  (GalaxyN3)22.jpg
# 1  (GalaxyN3)23.jpg
# 2  (GalaxyN3)24.jpg
# 3  (GalaxyN3)25.jpg
# 4  (GalaxyS4)11.jpg

# %%
def color_stats(q, iolock):
    
    while True:
        
        img_path = q.get()
        if img_path is None:
            break
            
        if type(img_path) is tuple:
            img = imread(train_path / img_path[0] / img_path[1])
            key = img_path[1]
        else:
            img = imread(test_path / img_path)
            key = img_path

        # Some images read return info in a 2nd dim. We only want the first dim.
        if img.shape == (2,):
            img = img[0]

        color_info[key] = (img[:, :, 0].mean(), img[:, :, 1].mean(), img[:, :, 2].mean(),
                           img[:, :, 0].std(),  img[:, :, 1].std(),  img[:, :, 2].std())

# %%
cols = ['a0', 'a1', 'a2', 's0', 's1', 's2']

for col in cols:
    train[col] = None
    test[col] = None

# %%
NCORE = 8

color_info = mp.Manager().dict()

# Using a queue since the image read is a bottleneck
q = mp.Queue(maxsize=NCORE)
iolock = mp.Lock()
pool = mp.Pool(NCORE, initializer=color_stats, initargs=(q, iolock))

for i in train_images:
    q.put(i)  # blocks until q below its max size

for i in test_images:
    q.put(i)  # blocks until q below its max size
    
# tell workers we're done
for _ in range(NCORE):  
    q.put(None)
pool.close()
pool.join()

color_info = dict(color_info)
# Out:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-2:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-7:
# Traceback (most recent call last):
# Process ForkPoolWorker-9:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-10:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-11:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-12:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-13:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-14:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-15:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-16:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Process ForkPoolWorker-17:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-18:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-19:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Process ForkPoolWorker-20:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Process ForkPoolWorker-21:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-22:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-23:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-24:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-25:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-26:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-27:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-28:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-29:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Process ForkPoolWorker-30:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-31:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Process ForkPoolWorker-32:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-33:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-34:
# Traceback (most recent call last):
# Process ForkPoolWorker-35:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-36:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-37:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
# Process ForkPoolWorker-38:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Process ForkPoolWorker-39:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-40:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-41:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-42:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-43:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-44:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-45:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-46:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Process ForkPoolWorker-47:
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
# Process ForkPoolWorker-48:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-49:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-50:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-51:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-52:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
# Process ForkPoolWorker-53:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-54:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-55:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-56:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-57:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-58:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-59:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-60:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-61:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-62:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-63:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-64:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-65:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-66:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-67:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-68:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-69:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-70:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-71:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
# Process ForkPoolWorker-72:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-73:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-74:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-75:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-76:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-77:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-78:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-80:
# Process ForkPoolWorker-79:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-81:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-82:
# Traceback (most recent call last):
# Process ForkPoolWorker-83:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-84:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Process ForkPoolWorker-85:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-86:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-87:
#   File "<ipython-input-7-75915a625f1a>", line 10, in color_stats
#     img = imread(train_path / img_path[0] / img_path[1])
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-88:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# ...
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# Process ForkPoolWorker-143:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-144:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# Process ForkPoolWorker-145:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-146:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-147:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-148:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-149:
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-150:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-151:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-152:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-153:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-154:
# Traceback (most recent call last):
# Process ForkPoolWorker-155:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-156:
# Process ForkPoolWorker-157:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-158:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-159:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
# Process ForkPoolWorker-160:
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-161:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-162:
# Traceback (most recent call last):
# Process ForkPoolWorker-163:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Process ForkPoolWorker-164:
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-165:
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-166:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-167:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-168:
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
# Traceback (most recent call last):
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-169:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
# Process ForkPoolWorker-170:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-171:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# Traceback (most recent call last):
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 103, in worker
#     initializer(*initargs)
#   File "<ipython-input-7-75915a625f1a>", line 13, in color_stats
#     img = imread(test_path / img_path)
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
for n, col in enumerate(cols):
    train[col] = train['fname'].apply(lambda x: color_info[x][n])
    test[col] = test['fname'].apply(lambda x: color_info[x][n])

# %%
train.sample(5)

# %%
test.sample(5)

# %%
y = train['camera'].values
X_train = train[cols].values
X_test = test[cols].values

# %%
clf = RandomForestClassifier(n_estimators=200)
clf.fit(X_train, y)

# %%
y_pred = clf.predict(X_test)
#'/home/mashrin/Downloads/camera/input/test'
clueless = pd.read_csv('/home/mashrin/Downloads/camera/input/sample_submission.csv', index_col='fname')
clueless['camera'] = y_pred
clueless.to_csv('clueless.csv')
